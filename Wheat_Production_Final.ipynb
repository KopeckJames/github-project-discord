# %%
#Load Prereq Libraries
import os
import sys
import time
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import path
from pathlib import Path

# %%
wheat_df = pd.read_csv('Resources/world food production.csv')

wheat_df.head()
# Out:
#         Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0                  7467702.0                  2279000.0
# 1                  7420515.0                  2279000.0
# 2                  8479074.0                  1947000.0
# 3                  9113779.0                  2230000.0
# 4                 10067913.0                  2282000.0
#
#    Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 0                     1873812.0                     56315.0
# ...

# %%
world_wheat = wheat_df.rename(columns={'Entity': 'Country'})

world_wheat.head()
# Out:
#        Country  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0                  7467702.0                  2279000.0
# 1                  7420515.0                  2279000.0
# 2                  8479074.0                  1947000.0
# 3                  9113779.0                  2230000.0
# 4                 10067913.0                  2282000.0
#
#    Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 0                     1873812.0                     56315.0
# ...

# %%
world_wheat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11912 entries, 0 to 11911
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              11912 non-null  object
#  1   Year                                 11912 non-null  int64
#  2   Maize Production (tonnes)            11912 non-null  float64
#  3   Rice  Production ( tonnes)           11912 non-null  float64
#  4   Yams  Production (tonnes)            11912 non-null  float64
#  5   Wheat Production (tonnes)            11912 non-null  float64
#  6   Tomatoes Production (tonnes)         11912 non-null  float64
#  7   Tea  Production ( tonnes )           11912 non-null  float64
#  8   Sweet potatoes  Production (tonnes)  11912 non-null  float64
#  9   Sunflower seed  Production (tonnes)  11912 non-null  float64
#  10  Sugar cane Production (tonnes)       11912 non-null  float64
# ...

# %%
world_wheat.columns
# Out:
# Index(['Country', 'Year', 'Maize Production (tonnes)',
#        'Rice  Production ( tonnes)', 'Yams  Production (tonnes)',
#        'Wheat Production (tonnes)', 'Tomatoes Production (tonnes)',
#        'Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)',
#        'Sunflower seed  Production (tonnes)', 'Sugar cane Production (tonnes)',
#        'Soybeans  Production (tonnes)', 'Rye  Production (tonnes)',
#        'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
#        'Peas, dry Production ( tonnes)', 'Palm oil  Production (tonnes)',
#        'Grapes  Production (tonnes)', 'Coffee, green Production ( tonnes)',
#        'Cocoa beans Production (tonnes)', 'Meat, chicken  Production (tonnes)',
#        'Bananas  Production ( tonnes)', 'Avocados Production (tonnes)',
#        'Apples Production (tonnes)'],
#       dtype='object')

# %%
columns_to_drop = ['Maize Production (tonnes)', 'Yams Production (tonnes)', 'Tomatoes Production (tonnes)', 'Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)',
                   'Sunflower seed  Production (tonnes)', 'Sugar cane Production (tonnes)', 'Rice Production ( tonnes)', 'Yams Production (tonnes)',
                   'Soybeans  Production (tonnes)', 'Rye  Production (tonnes)',
                   'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
                   'Peas, dry Production ( tonnes)', 'Palm oil  Production (tonnes)',
                   'Grapes  Production (tonnes)', 'Coffee, green Production ( tonnes)',
                   'Cocoa beans Production (tonnes)', 'Meat, chicken  Production (tonnes)',
                   'Bananas  Production ( tonnes)', 'Avocados Production (tonnes)',
                   'Apples Production (tonnes)']

columns_to_drop_existing = [col for col in columns_to_drop if col in world_wheat.columns]

world_wheat.drop(columns=columns_to_drop_existing, axis=1, inplace=True)

world_wheat.head()
# Out:
#        Country  Year  Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0  Afghanistan  1961                    319000.0                  7467702.0
# 1  Afghanistan  1962                    319000.0                  7420515.0
# 2  Afghanistan  1963                    319000.0                  8479074.0
# 3  Afghanistan  1964                    380000.0                  9113779.0
# 4  Afghanistan  1965                    380000.0                 10067913.0
#
#    Wheat Production (tonnes)
# 0                  2279000.0
# 1                  2279000.0
# 2                  1947000.0
# 3                  2230000.0
# 4                  2282000.0

# %%
#For Rice Production, Yams Production and Wheat Production, we're converting the values to billion tonnes
world_wheat['Wheat Production (tonnes)'] = world_wheat['Wheat Production (tonnes)'] / 1000000000


world_wheat.head()
# Out:
#        Country  Year  Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0  Afghanistan  1961                    319000.0                  7467702.0
# 1  Afghanistan  1962                    319000.0                  7420515.0
# 2  Afghanistan  1963                    319000.0                  8479074.0
# 3  Afghanistan  1964                    380000.0                  9113779.0
# 4  Afghanistan  1965                    380000.0                 10067913.0
#
#    Wheat Production (tonnes)
# 0                   0.002279
# 1                   0.002279
# 2                   0.001947
# 3                   0.002230
# 4                   0.002282

# %%
world_wheat.rename(columns={'Wheat Production (tonnes)': 'Wheat Production (billion tonnes)'}, inplace=True)

world_wheat.head()
# Out:
#        Country  Year  Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0  Afghanistan  1961                    319000.0                  7467702.0
# 1  Afghanistan  1962                    319000.0                  7420515.0
# 2  Afghanistan  1963                    319000.0                  8479074.0
# 3  Afghanistan  1964                    380000.0                  9113779.0
# 4  Afghanistan  1965                    380000.0                 10067913.0
#
#    Wheat Production (billion tonnes)
# 0                           0.002279
# 1                           0.002279
# 2                           0.001947
# 3                           0.002230
# 4                           0.002282

# %%
world_wheat = world_wheat[['Country', 'Year', 'Wheat Production (billion tonnes)']]
world_wheat.head()
# Out:
#        Country  Year  Wheat Production (billion tonnes)
# 0  Afghanistan  1961                           0.002279
# 1  Afghanistan  1962                           0.002279
# 2  Afghanistan  1963                           0.001947
# 3  Afghanistan  1964                           0.002230
# 4  Afghanistan  1965                           0.002282

# %%
#Get Dataframe for all proudctions in each year
yearly_production = world_wheat.groupby('Year')['Wheat Production (billion tonnes)'].sum().reset_index()
yearly_production.tail()
# Out:
#     Year  Wheat Production (billion tonnes)
# 56  2017                           5.701665
# 57  2018                           5.991785
# 58  2019                           6.011762
# 59  2020                           5.560685
# 60  2021                           5.479791

# %%
#Graph of Russia Wheat Production over the years
russia_wheat = world_wheat[world_wheat['Country'] == 'Russia']
russia_wheat.groupby('Year')['Wheat Production (billion tonnes)'].sum().plot(kind='bar', figsize=(12, 6))
plt.title('Russia Wheat Production (billion tonnes) over the years')
plt.ylabel('Wheat Production (billion tonnes)')
xticks = np.arange(1961, 2022, 1)
plt.show()

# %%
#Graph of yearly wheat production worldwide (line graph)
yearly_production.plot(x='Year', y='Wheat Production (billion tonnes)', kind='line', figsize=(12, 6))
plt.title('Worldwide Wheat Production (billion tonnes) over the years')
plt.ylabel('Wheat Production (billion tonnes)')
plt.xticks(yearly_production['Year'], rotation=90)
#plt.savefig('Resources/World_Wheat_Production_Line.png')
plt.show()

# %%
#Bar graph of yearly wheat production worldwide
yearly_production.plot(x='Year', y='Wheat Production (billion tonnes)', kind='bar', figsize=(12, 6))
plt.title('Worldwide Wheat Production (billion tonnes) over the years')
plt.ylabel('Wheat Production (billion tonnes)')
#plt.savefig('Resources/World_Wheat_Production_Bar.png')
plt.show()
